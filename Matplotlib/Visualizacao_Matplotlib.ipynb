# %% [markdown]
# ##Aula 1

# %% [markdown]
# ### Fazendo as primerias visualizações

# %%
import pandas as pd

# %%
df = pd.read_csv('monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#inline para os gráficos serem plotados automaticamente no notebook

# %%
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['data'], df['temperatura'])
plt.title('Temperatura ao longo dos anos')
# Out:
# Text(0.5, 1.0, 'Temperatura ao longo dos anos')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no período')
# Out:
# Text(0.5, 1.0, 'Temperatura no período')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no período')
eixo.set_ylabel('Temperatura')
eixo.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'mediumpurple')

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %% [markdown]
# ##Aula 02

# %% [markdown]
# ### Customizando nossas visualizações

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green', lw = 4) #line weidth

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green', lw = 0.4) #line weidth

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green', ls = 'dotted') #line style

eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
import datetime

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green', marker = 'o')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1]) #define limites dos gráficos
eixo.plot(df['data'], df['temperatura'], color = 'green')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura no período', fontsize = 25)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4]) #posição x tamanho

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no período', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'best', fontsize = 15)

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura no período', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'best', fontsize = 15)
eixo2.set_xlabel('Data', fontsize = 20)
eixo2.set_ylabel('Temperatura', fontsize = 20)

eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_title('Temperatura no período', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2014, 1, 1))
eixo.set_title('Temperatura 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'best', fontsize = 15)
eixo2.set_xlabel('Data', fontsize = 20)
eixo2.set_ylabel('Temperatura', fontsize = 20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2014, 1, 1))
eixo2.set_title('Temperatura no período', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Attempting to set identical left == right == 735234.0 results in singular transformations; automatically expanding.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Attempting to set identical left == right == 735234.0 results in singular transformations; automatically expanding.
#   app.launch_new_instance()
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.67, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_title('Temperatura no período', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.67, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_title('Temperatura 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2015, 1, 1))
eixo2.set_title('Temperatura no período', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.67, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2015, 1, 1))
eixo2.set_title('Temperatura no período', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.67, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura Maio 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2015, 1, 1))
eixo2.set_title('Temperatura em 2014', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize = (15, 8))

eixo  = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.67, 0.65, 0.3, 0.3]) #posição x tamanho

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura Maio 2014', fontsize = 25, pad = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)

azul_esquerda = df['data'] < datetime.datetime(2014, 5, 1)
azul_direita  = df['data'] > datetime.datetime(2014, 6, 1)

eixo2.grid(True)
eixo2.plot(df['data'], df['temperatura'], color = 'g')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'],
           color = 'b')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'],
           color = 'b')
eixo2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo2.set_title('Temperatura em 2014', fontsize = 15)
eixo2.legend(['Temperatura'], loc = 'best', fontsize = 10)
eixo2.set_xlabel('Data', fontsize = 10)
eixo2.set_ylabel('Temperatura', fontsize = 10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# ##Aula 03

# %% [markdown]
# ### Diversos Gráficos

# %%
fig = plt.figure(figsize=(15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend('Temperatura', loc = 'lower right')
eixo.grid(True)

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

# %%
fig = plt.figure(figsize=(15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend('Temperatura', loc = 'lower right')
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #indice da temperatura maxima (data)
y1 = max(df['temperatura'])

eixo.annotate('Máximo', xy=(x1, y1), fontsize = 15)

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

# %%
fig = plt.figure(figsize=(15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend('Temperatura', loc = 'lower right')
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #indice da temperatura maxima (data)
y1 = max(df['temperatura'])

eixo.annotate('Máximo', xy=(x1, y1), fontsize = 15)

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

# %%
fig = plt.figure(figsize=(15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend('Temperatura', loc = 'lower right')
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #indice da temperatura maxima (data)
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 4000]
y2 = max(df['temperatura']) - 3

eixo.annotate('Máximo', xy=(x1, y1), fontsize = 15,
              xytext = (x2, y2), arrowprops = dict(facecolor = 'k'))

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

# %%
fig = plt.figure(figsize=(15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend('Temperatura', loc = 'lower right')
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()] #indice da temperatura maxima (data)
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 4000]
y2 = max(df['temperatura']) - 3

eixo.annotate('Máximo', xy=(x1, y1), fontsize = 15,
              xytext = (x2, y2), arrowprops = dict(facecolor = 'k'))

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

x1 = df['data'][df['temperatura'].idxmin()] #indice da temperatura mínima (data)
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() - 4000]
y2 = min(df['temperatura']) + 3

eixo.annotate('Mínimo', xy=(x1, y1), fontsize = 15,
              xytext = (x2, y2), arrowprops = dict(facecolor = 'k'))

eixo.axhline(max(df['temperatura']), color = 'k', ls = '--')
eixo.axhline(min(df['temperatura']), color = 'k', ls = '--')

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize = 15)
eixo.set_ylabel('Temperatura Média', fontsize = 15)
# Out:
# Text(0, 0.5, 'Temperatura Média')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize = 15)
eixo.set_ylabel('Temperatura Média', fontsize = 15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color = cores)
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize = 15)
eixo.set_ylabel('Temperatura Média', fontsize = 15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color = cores, edgecolor = 'k')
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
eixo.set_xlabel('Dia da semana', fontsize = 15)
eixo.set_ylabel('Temperatura Média', fontsize = 15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index)
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
         autopct = '%.1f%%')
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0, 0, 1, 1])

explodir = [0.1, 0, 0, 0, 0, 0, 0.1]
cores = ['b', 'gray', 'gray', 'gray', 'gray', 'gray', 'cyan']

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
         colors = cores, autopct = '%.1f%%', explode = explodir, shadow = True)
eixo.set_title('Temperatura por dia da semana', fontsize = 15, pad = 10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')
