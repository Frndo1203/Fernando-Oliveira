# %% [markdown]
# #Aula04

# %% [markdown]
# ## Íris

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
df['espécie'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.grid(True)
eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 15)
eixo.set_xlabel('Comprimento da Sépala', fontsize = 15)
eixo.set_ylabel('Largura da Sépala', fontsize = 15)
# Out:
# Text(0, 0.5, 'Largura da Sépala')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.grid(True)
eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 15)
eixo.set_xlabel('Comprimento da Sépala', fontsize = 15)
eixo.set_ylabel('Largura da Sépala', fontsize = 15)
eixo.tick_params(labelsize = 15)

# %%
df['espécie'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}

for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
               color = cores[especie])


  eixo.grid(True)
  eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 15)
  eixo.set_xlabel('Comprimento da Sépala', fontsize = 15)
  eixo.set_ylabel('Largura da Sépala', fontsize = 15)
  eixo.tick_params(labelsize = 15)
  eixo.legend(cores, fontsize = 20, loc = 'upper right')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}


for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
               color = cores[especie], marker = marcadores[especie])


  eixo.grid(True)
  eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 15)
  eixo.set_xlabel('Comprimento da Sépala', fontsize = 15)
  eixo.set_ylabel('Largura da Sépala', fontsize = 15)
  eixo.tick_params(labelsize = 15)
  eixo.legend(cores, fontsize = 20, loc = 'upper right')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}


for especie in df['espécie'].unique():
  tmp = df[df['espécie'] == especie]
  eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
               color = cores[especie], marker = marcadores[especie],
               s = 100)


  eixo.grid(True)
  eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 15)
  eixo.set_xlabel('Comprimento da Sépala', fontsize = 15)
  eixo.set_ylabel('Largura da Sépala', fontsize = 15)
  eixo.tick_params(labelsize = 15)
  eixo.legend(cores, fontsize = 20, loc = 'upper right')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.boxplot(df['largura_pétala'])
eixo.set_title('Gráfico de caixa', fontsize = 15, pad = 10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize = (8, 5))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.boxplot(df.drop('espécie', axis = 1).values)
eixo.set_title('Gráfico de caixa', fontsize = 15, pad = 10)
eixo.set_xticklabels(df.drop('espécie', axis = 1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
 fig = plt.figure(figsize = (8, 5))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.boxplot(df.drop('espécie', axis = 1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize = 15, pad = 10)
eixo.set_xticklabels(df.drop('espécie', axis = 1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize = (8, 5))
eixo = fig.add_axes([0, 0, 1, 1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis = 1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize = 15, pad = 10)
eixo.set_xticklabels(df.drop('espécie', axis = 1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color = cor)

# %%
fig = plt.figure(figsize = (8, 5))
eixo = fig.add_axes([0, 0, 1, 1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis = 1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize = 15, pad = 10)
eixo.set_xticklabels(df.drop('espécie', axis = 1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
  caixa.set(color = cor)

for outlier in caixas['fliers']:
  outlier.set(marker = 'x', markersize = 8)

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.hist(df['comprimento_pétala'])
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.hist(df['comprimento_pétala'], bins = 20, orientation = 'horizontal')
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.hist(df['comprimento_pétala'], bins = 20, density = True)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
              xy = (5, 25), fontsize = 15)
# Out:
# Text(5, 25, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
              xy = (5, 25), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 25), fontsize = 10,
              xytext = (mu - 1, 20), arrowprops = dict(facecolor = 'k', lw = 0.1))
# Out:
# Text(2.7586666666666693, 20, 'média')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy = (5, 25), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 25), fontsize = 10,
              xytext = (mu - 1, 20), arrowprops = dict(facecolor = 'k', lw = 0.1))

eixo.axvline(df['comprimento_pétala'].median(), color = 'g', ls = '--', lw = 1)
eixo.annotate('mediana', xy = (df['comprimento_pétala'].median(), 30), fontsize = 10,
              xytext = (df['comprimento_pétala'].median() + 0.5, 32),
              arrowprops = dict(facecolor = 'k', lw = 0.1))
# Out:
# Text(4.85, 32, 'mediana')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

df_iv = df[df['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'], bins = 20)
eixo.set_title('Íris Versicolor', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy = (4.7, 6), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 6.5), fontsize = 10,
              xytext = (mu - 0.5, 5.5), arrowprops = dict(facecolor = 'k', lw = 0.1))

eixo.axvline(df['comprimento_pétala'].median(), color = 'g', ls = '--', lw = 1)
eixo.annotate('mediana', xy = (df_iv['comprimento_pétala'].median(), 6.5), fontsize = 10,
              xytext = (df_iv['comprimento_pétala'].median() - 0.5, 7),
              arrowprops = dict(facecolor = 'k', lw = 0.1))
# Out:
# Text(3.8499999999999996, 7, 'mediana')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

df_iv = df[df['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'], bins = 20)
eixo.set_title('Íris Versicolor', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy = (4.7, 6), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 6.5), fontsize = 10,
              xytext = (mu - 0.5, 5.5), arrowprops = dict(facecolor = 'k', lw = 0.1))

eixo.axvline(df['comprimento_pétala'].median(), color = 'g', ls = '--', lw = 1)
eixo.annotate('mediana', xy = (df_iv['comprimento_pétala'].median(), 6.5), fontsize = 10,
              xytext = (df_iv['comprimento_pétala'].median() - 0.5, 7),
              arrowprops = dict(facecolor = 'k', lw = 0.1))

fig.savefig('histograma_iv.png', box_inches = 'tight')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins = 20)
eixo.set_title('Íris Versicolor', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy = (1.7, 9), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 6.5), fontsize = 10,
              xytext = (mu - 0.2, 13.5), arrowprops = dict(facecolor = 'k', lw = 0.1))

eixo.axvline(df_is['comprimento_pétala'].median(), color = 'g', ls = '--', lw = 2)
eixo.annotate('mediana', xy = (df_is['comprimento_pétala'].median(), 12), fontsize = 10,
              xytext = (df_is['comprimento_pétala'].median() + 0.2, 13),
              arrowprops = dict(facecolor = 'k', lw = 0.1))

fig.savefig('histograma_is.png', box_inches = 'tight')

# %%
fig = plt.figure(figsize = (5, 4))
eixo = fig.add_axes([0, 0, 1, 1])

df_ivc = df[df['espécie'] == 'Iris-virginica']

mu, sigma = df_ivc['comprimento_pétala'].mean(), df_ivc['comprimento_pétala'].std()

eixo.hist(df_ivc['comprimento_pétala'], bins = 20)
eixo.set_title('Íris Versicolor', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
              xy = (6.3, 7), fontsize = 15)

eixo.axvline(mu, color = 'k', ls = '--', lw = 1)
eixo.annotate('média', xy = (mu, 6.5), fontsize = 10,
              xytext = (mu - 0.3, 8), arrowprops = dict(facecolor = 'k', lw = 0.1))

eixo.axvline(df_ivc['comprimento_pétala'].median(), color = 'g', ls = '--', lw = 1)
eixo.annotate('mediana', xy = (df_ivc['comprimento_pétala'].median(), 7), fontsize = 10,
              xytext = (df_ivc['comprimento_pétala'].median() + 0.2, 8),
              arrowprops = dict(facecolor = 'k', lw = 0.1))

fig.savefig('histograma_ivc.png', box_inches = 'tight')

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivc.png').size
combinada = Image.new('RGB', (3*largura, altura))
intervalo = 0

for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png',
                               'histograma_ivc.png']):
  combinada.paste(imagem, (intervalo, 0))
  intervalo += largura + 1

combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1080x288 at 0x7FC04167E208>
